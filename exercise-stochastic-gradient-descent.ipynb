# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/stochastic-gradient-descent).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise you'll train a neural network on the *Fuel Economy* dataset and then explore the effect of the learning rate and batch size on SGD.
#
# When you're ready, run this next cell to set everything up!

# %%
# Setup plotting
import matplotlib.pyplot as plt
from learntools.deep_learning_intro.dltools import animate_sgd
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex3 import *
# Out:
# 2025-12-31 19:16:45.871741: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-31 19:16:45.871884: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-31 19:16:46.071500: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /tmp/ipykernel_18/3305082411.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# In the *Fuel Economy* dataset your task is to predict the fuel economy of an automobile given features like its type of engine or the year it was made.
#
# First load the dataset by running the cell below.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.model_selection import train_test_split

fuel = pd.read_csv('../input/dl-course-data/fuel.csv')

X = fuel.copy()
# Remove target
y = X.pop('FE')

preprocessor = make_column_transformer(
    (StandardScaler(),
     make_column_selector(dtype_include=np.number)),
    (OneHotEncoder(sparse_output=False),
     make_column_selector(dtype_include=object)),
)

X = preprocessor.fit_transform(X)
y = np.log(y) # log transform target instead of standardizing

input_shape = [X.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# Input shape: [50]

# %%
cs1 = make_column_selector(dtype_include=np.number)
sel1 = cs1.__call__(fuel.copy())
cs2 = make_column_selector(dtype_include=object)
sel2 = cs2.__call__(fuel.copy())
print("len num: {}, len object: {}".format(len(sel1), len(sel2)))
sel2
# Out:
# len num: 10, len object: 4
# ['Transmission', 'AirAspirationMethod', 'DriveDesc', 'CarlineClassDesc']

# %% [markdown]
# Take a look at the data if you like. Our target in this case is the `'FE'` column and the remaining columns are the features.

# %%
# Uncomment to see original data
fuel.shape
# Uncomment to see processed features
pd.DataFrame(X).shape
# Out:
# (1107, 50)

# %% [markdown]
# Run the next cell to define the network we'll use for this task.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dropout(0.2), # Randomly turns off 20% of neurons to prevent overfitting
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1),
])

# %% [markdown]
# # 1) Add Loss and Optimizer
#
# Before training the network we need to define the loss and optimizer we'll use. Using the model's `compile` method, add the Adam optimizer and MAE loss.

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# # 2) Train Model
#
# Once you've defined the model and compiled it with a loss and optimizer you're ready for training. Train the network for 200 epochs with a batch size of 128. The input data is `X` with target `y`.

# %%
# YOUR CODE HERE
history = history = model.fit(
    X, y,
    batch_size=128,
    epochs=200,
)

# Check your answer
q_2.check()
# Out:
# Epoch 1/200
# 9/9 [==============================] - 1s 6ms/step - loss: 2.6581
# Epoch 2/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.1282
# Epoch 3/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6262
# Epoch 4/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4427
# Epoch 5/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3334
# Epoch 6/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2921
# Epoch 7/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2740
# Epoch 8/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2592
# Epoch 9/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2420
# Epoch 10/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2330
# Epoch 11/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2152
# Epoch 12/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2210
# Epoch 13/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2015
# Epoch 14/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1964
# Epoch 15/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2126
# Epoch 16/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1979
# Epoch 17/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1856
# Epoch 18/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1785
# Epoch 19/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1779
# Epoch 20/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1708
# Epoch 21/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1720
# Epoch 22/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1636
# Epoch 23/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1611
# Epoch 24/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1595
# Epoch 25/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1568
# Epoch 26/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1497
# Epoch 27/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1562
# Epoch 28/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1464
# Epoch 29/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1388
# Epoch 30/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1405
# Epoch 31/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1448
# Epoch 32/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1446
# Epoch 33/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1507
# Epoch 34/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1423
# Epoch 35/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1282
# Epoch 36/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1199
# Epoch 37/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1214
# Epoch 38/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1225
# Epoch 39/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1192
# Epoch 40/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1145
# Epoch 41/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1174
# Epoch 42/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1166
# Epoch 43/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1166
# Epoch 44/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1117
# Epoch 45/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1090
# Epoch 46/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1052
# Epoch 47/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1062
# Epoch 48/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1017
# Epoch 49/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1049
# Epoch 50/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1155
# Epoch 51/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1098
# Epoch 52/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1139
# Epoch 53/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1112
# Epoch 54/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0996
# Epoch 55/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0948
# Epoch 56/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0998
# Epoch 57/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0981
# Epoch 58/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0962
# Epoch 59/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0982
# Epoch 60/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0945
# Epoch 61/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0948
# Epoch 62/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0916
# Epoch 63/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0904
# Epoch 64/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0954
# Epoch 65/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0933
# Epoch 66/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1027
# Epoch 67/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0940
# Epoch 68/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0878
# Epoch 69/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0861
# Epoch 70/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0867
# Epoch 71/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0857
# Epoch 72/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0879
# Epoch 73/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0844
# Epoch 74/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0830
# Epoch 75/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0805
# Epoch 76/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0786
# Epoch 77/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0843
# Epoch 78/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0791
# Epoch 79/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0903
# Epoch 80/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0934
# Epoch 81/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0847
# Epoch 82/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0868
# Epoch 83/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0853
# Epoch 84/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0795
# Epoch 85/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0801
# Epoch 86/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0819
# Epoch 87/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0791
# Epoch 88/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0833
# Epoch 89/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0756
# Epoch 90/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0832
# Epoch 91/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0849
# Epoch 92/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0781
# Epoch 93/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0745
# Epoch 94/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0744
# Epoch 95/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0780
# Epoch 96/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0746
# Epoch 97/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0707
# Epoch 98/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0707
# Epoch 99/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0735
# Epoch 100/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0767
# Epoch 101/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0714
# Epoch 102/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0688
# Epoch 103/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0690
# Epoch 104/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0738
# Epoch 105/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0709
# Epoch 106/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0684
# Epoch 107/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0707
# Epoch 108/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0671
# Epoch 109/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0694
# Epoch 110/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0700
# Epoch 111/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0688
# Epoch 112/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0669
# Epoch 113/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0687
# Epoch 114/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0699
# Epoch 115/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0641
# Epoch 116/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0700
# Epoch 117/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0728
# Epoch 118/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0680
# Epoch 119/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0721
# Epoch 120/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0684
# Epoch 121/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0679
# Epoch 122/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0652
# Epoch 123/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0696
# Epoch 124/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0675
# Epoch 125/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0646
# Epoch 126/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0661
# Epoch 127/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0673
# Epoch 128/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0661
# Epoch 129/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0645
# Epoch 130/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0651
# Epoch 131/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0628
# Epoch 132/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0648
# Epoch 133/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0608
# Epoch 134/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0637
# Epoch 135/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0652
# Epoch 136/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0720
# Epoch 137/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0640
# Epoch 138/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0599
# Epoch 139/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0606
# Epoch 140/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0594
# Epoch 141/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0592
# Epoch 142/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0574
# Epoch 143/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0629
# Epoch 144/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0583
# Epoch 145/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0608
# Epoch 146/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0607
# Epoch 147/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0547
# Epoch 148/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0543
# Epoch 149/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0543
# Epoch 150/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0557
# Epoch 151/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0547
# Epoch 152/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0596
# Epoch 153/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0576
# Epoch 154/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0598
# Epoch 155/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0588
# Epoch 156/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0570
# Epoch 157/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0574
# Epoch 158/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0553
# Epoch 159/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0541
# Epoch 160/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0546
# Epoch 161/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0521
# Epoch 162/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0579
# Epoch 163/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0537
# Epoch 164/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0545
# Epoch 165/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0533
# Epoch 166/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0534
# Epoch 167/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0527
# Epoch 168/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0553
# Epoch 169/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0574
# Epoch 170/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0557
# Epoch 171/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0526
# Epoch 172/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0506
# Epoch 173/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0525
# Epoch 174/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0523
# Epoch 175/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0511
# Epoch 176/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0494
# Epoch 177/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0505
# Epoch 178/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0572
# Epoch 179/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0535
# Epoch 180/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0503
# Epoch 181/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0492
# Epoch 182/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0495
# Epoch 183/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0530
# Epoch 184/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0496
# Epoch 185/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0546
# Epoch 186/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0545
# Epoch 187/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0518
# Epoch 188/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0555
# Epoch 189/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0491
# Epoch 190/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0485
# Epoch 191/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0488
# Epoch 192/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0503
# Epoch 193/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0491
# Epoch 194/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0492
# Epoch 195/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0515
# Epoch 196/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0492
# Epoch 197/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0529
# Epoch 198/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0562
# Epoch 199/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0572
# Epoch 200/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0496
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# The last step is to look at the loss curves and evaluate the training. Run the cell below to get a plot of the training loss.

# %%
import pandas as pd

history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5. You can change this to get a different view.
history_df.loc[5:, ['loss']].plot();

# %% [markdown]
# # 3) Evaluate Training
#
# If you trained the model longer, would you expect the loss to decrease further?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# This depends on how the loss has evolved during training: if the learning curves have levelled off, there won't usually be any advantage to training for additional epochs.  Conversely, if the loss appears to still be decreasing, then training for longer could be advantageous.

# %% [markdown]
# With the learning rate and the batch size, you have some control over:
# - How long it takes to train a model
# - How noisy the learning curves are
# - How small the loss becomes
#
# To get a better understanding of these two parameters, we'll look at the linear model, our ppsimplest neural network. Having only a single weight and a bias, it's easier to see what effect a change of parameter has.
#
# The next cell will generate an animation like the one in the tutorial. Change the values for `learning_rate`, `batch_size`, and `num_examples` (how many data points) and then run the cell. (It may take a moment or two.) Try the following combinations, or try some of your own:
#
# | `learning_rate` | `batch_size` | `num_examples` |
# |-----------------|--------------|----------------|
# | 0.05            | 32           | 256            |
# | 0.05            | 2            | 256            |
# | 0.05            | 128          | 256            |
# | 0.02            | 32           | 256            |
# | 0.2             | 32           | 256            |
# | 1.0             | 32           | 256            |
# | 0.9             | 4096         | 8192           |
# | 0.99            | 4096         | 8192           |

# %%
# YOUR CODE HERE: Experiment with different values for the learning rate, batch size, and number of examples
learning_rate = 0.05
batch_size = 128
num_examples = 1024

animate_sgd(
    learning_rate=learning_rate,
    batch_size=batch_size,
    num_examples=num_examples,
    # You can also change these, if you like
    steps=50, # total training steps (batches seen)
    true_w=3.0, # the slope of the data
    true_b=2.0, # the bias of the data
)
# Out:
# <video width="800" height="300" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # 4) Learning Rate and Batch Size
#
# What effect did changing these parameters have? After you've thought about it, run the cell below for some discussion.

# %%
# View the solution (Run this cell to receive credit!)
q_4.check()
# Out:
# Correct:
#
#
# You probably saw that smaller batch sizes gave noisier weight updates and loss curves. This is because each batch is a small *sample* of data and smaller samples tend to give noisier estimates. Smaller batches can have an "averaging" effect though which can be beneficial.
#
# Smaller learning rates make the updates smaller and the training takes longer to converge. Large learning rates can speed up training, but don't "settle in" to a minimum as well. When the learning rate is too large, the training can fail completely. (Try setting the learning rate to a large value like 0.99 to see this.)

# %% [markdown]
# # Keep Going #
#
# Learn how to [**improve your model's performance**](https://www.kaggle.com/ryanholbrook/overfitting-and-underfitting) by tuning capacity or adding an early stopping callback.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
